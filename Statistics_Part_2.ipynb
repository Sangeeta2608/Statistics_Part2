# %% [markdown]
# #1.What is hypothesis testing in statistics?
# Hypothesis testing in statistics is a method used to make decisions or inferences about population parameters based on sample data.It involves making an assumption and then using statistical methods to determine whether the data supports or refutes that assumption.

# %% [markdown]
# #2.What is the null hypothesis, and how does it differ from the alternative hypothesis?
# Null hypothesis is the default or starting assumption.It typically states that there is no effect, no difference, or no relationship between variables.
# Example: H₀:The average height of students is 170 cm.
# Alternative Hypothesis represents what are we trying to prove that there is an effect, difference, or relationship.
# Example: H₁:The average height of students is not 170 cm.

# %% [markdown]
# #3.What is the significance level in hypothesis testing, and why is it important?
# The significance level, often denoted by α(alpha), is a threshold that you set before conducting a hypothesis test. It represents the maximum probability of making a Type I error—rejecting the null hypothesis (H₀) when it is actually true.

# %% [markdown]
# #4.What does a P-value represent in hypothesis testing?
# The p-value in hypothesis testing represents the probability of obtaining a test result at least as extreme as the one observed, assuming that the null hypothesis(H₀) is true.

# %% [markdown]
# #5.How do you interpret the P-value in hypothesis testing?
# The p-value helps us to decide whether to reject the null hypothesis(H₀) based on the evidence from your sample data.
# The p-value is the probability of obtaining results as extreme as(or more extreme than) the observed results if H₀ is true.
# A small p-value (e.g., < 0.01) = strong evidence against H₀.
# A large p-value (e.g., > 0.10) = weak or no evidence against H₀.
# Failing to reject H₀ ≠ proving H₀ is true. It only means you don't have enough evidence to say otherwise.

# %% [markdown]
# #6.What are Type 1 and Type 2 errors in hypothesis testing?
# Type I Error(False Positive):Rejecting the null hypothesis (H₀) when it is actually true.We say there's an effect or difference, but there isn't.
# Probability of Type I error = α (significance level).
# Type II Error (False Negative):Failing to reject the null hypothesis (H₀) when it is actually false.We miss a real effect or difference.
# Probability of Type II error = β.Power of a test = 1 - β (probability of detecting a real effect).

# %% [markdown]
# #7.What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
# The difference between a one-tailed and a two-tailed test in hypothesis testing lies in what kind of effect or difference you're testing for — specifically, the direction of the effect.
# one-tailed test:Tests for an effect in one specific direction either greater than or less than.
# Two-tailed test:Tests for an effect in either direction — different from the null, but not specifically greater or smaller.

# %% [markdown]
# #8. What is the Z-test, and when is it used in hypothesis testing?
# A Z-test is a statistical test used to determine whether there is a significant difference between sample data and a population parameter (like the mean or proportion), under the assumption that the data follows a normal distribution and you know the population standard deviation (σ).
# It is used when:1.The population standard deviation (σ) is known.
# 2.The sample size is large (typically n ≥ 30) OR the population is normally distributed.
# 3.You are testing the mean or proportion.

# %% [markdown]
# #9.How do you calculate the Z-score, and what does it represent in hypothesis testing?
# Z-score calculation:
# Z=(x-μ )/(σ/underroot n)
# where 𝑥= sample mean
# 𝜇= population mean (under H₀)
# σ = population standard deviation
# n = sample size
# Z-score represents
# A positive Z-score means the sample mean is above the population mean.
# A negative Z-score means the sample mean is below the population mean.

# %% [markdown]
# #10.What is the T-distribution, and when should it be used instead of the normal distribution.
# The t-distribution is a probability distribution used in hypothesis testing when the sample size is small and/or the population standard deviation (σ) is unknown.
# It looks similar to the normal distribution (bell-shaped and symmetric), but it has heavier tails — meaning it accounts for more variability when working with smaller samples.
# The fatter tails of the t-distribution provide a more conservative estimate of statistical significance when your sample is small or your estimate of variability (s) is less reliable.
# T-distribution  is used when:
# 1.Sample size is small (typically n < 30)
# 2.Population standard deviation (σ) is unknown
# 3.Data are approximately normally distributed

# %% [markdown]
# #11.What is the difference between a Z-test and a T-test?
# Both the Z-test and the T-test are used to determine whether there's a significant difference between a sample statistic (like a mean) and a population parameter, or between two groups. The main difference lies in the assumptions about the population standard deviation and the sample size.
# Z-test used when:
# Population standard deviation (σ) is known.
# Sample size is large (n ≥ 30).
# The data is approximately normally distributed (or the Central Limit Theorem applies).
# T-test is used when:
# Population standard deviation (σ) is unknown.
# Sample size is small (n < 30).
# The population is normally distributed, or the sample is approximately normal.

# %% [markdown]
# #12.What is the T-test, and how is it used in hypothesis testing?
# A T-test is a statistical method used in hypothesis testing to determine whether there is a significant difference between means — either:
# Between a sample mean and a known value (one-sample t-test),
# Two related samples (paired t-test), or
# Two independent samples (independent t-test).
# It’s most commonly used when the population standard deviation (σ) is unknown and the sample size is small (typically n < 30).
# A T-test is used when:
# 1.we don't know σ (the population standard deviation),
# 2.working with small samples,
# 3.the data is approximately normally distributed.

# %% [markdown]
# #13.What is the relationship between Z-test and T-test in hypothesis testing?
# The Z-test and T-test are both used to assess whether a sample mean (or difference between means) is statistically different from a known value or another sample mean. They are conceptually very similar — the main difference lies in assumptions about the data and sample characteristics.

# %% [markdown]
# #14. What is a confidence interval, and how is it used to interpret statistical results?
# A confidence interval (CI) is a range of values used to estimate an unknown population parameter (such as the mean or proportion) based on sample data. It provides not just a single estimate, but a range that likely contains the true value.

# %% [markdown]
# #15.What is the margin of error, and how does it affect the confidence interval?
# The margin of error is the maximum amount you expect your sample estimate to differ from the true population value, given a certain level of confidence. It’s a critical part of constructing and interpreting a confidence interval.
# Wider margin of error → wider confidence interval → less precise estimate.
# Smaller margin of error → narrower confidence interval → more precise estimate.

# %% [markdown]
# #16.How is Bayes' Theorem used in statistics, and what is its significance?
# Bayes’ Theorem is a fundamental concept in probability and statistics that describes how to update the probability of a hypothesis based on new evidence or information.
# It provides a mathematical way to revise beliefs (probabilities) when more data becomes available.
# P(A∣B)=P(B∣A)⋅P(A)/p(B)
# where,P(A) = Prior probability (your initial belief about event A)
# P(B∣A) = Likelihood (probability of seeing B if A is true
# P(B) = Total probability of B (all ways B can happen)
# P(A∣B) = Posterior probability (updated belief about A after seeing B)​

# %% [markdown]
# #17. What is the Chi-square distribution, and when is it used?
# The Chi-square distribution is a right-skewed, continuous probability distribution that arises in statistics when you're dealing with sums of squared values, especially in categorical data analysis.
# It is used mainly for testing relationships between categorical variables and evaluating variance.

# %% [markdown]
# #18.What is the Chi-square goodness of fit test, and how is it applied?
# The Chi-Square Goodness of Fit Test is a statistical test used to determine whether the observed frequencies of a single categorical variable match the expected frequencies based on a specified theoretical distribution.
# It helps answer the question:“Do the observed data fit a specific expected distribution?”

# %% [markdown]
# #19.What is the F-distribution, and when is it used in hypothesis testing?
# The F-distribution is a continuous, right-skewed probability distribution that arises when comparing two variances or testing multiple means. It is mainly used in ANOVA (Analysis of Variance) and in comparing variances between two or more samples.

# %% [markdown]
# #20.What is an ANOVA test, and what are its assumptions?
# ANOVA (Analysis of Variance) is a statistical test used to determine if there are statistically significant differences between the means of three or more groups. It helps answer the question:“Are the group means equal or do at least one of them differ significantly?”
# The results of an ANOVA to be valid, certain assumptions must be met:
# 1. Independence of Observations
# Each observation in the data should be independent of the others. This means that the values in one group should not influence the values in another group.
# 2. Normality
# The data in each group should be approximately normally distributed. This assumption can be checked using a normality test (e.g., Shapiro-Wilk test) or by visualizing the data with histograms or Q-Q plots.
# 3. Homogeneity of Variances (Homoscedasticity)
# The variance within each group should be approximately equal. This assumption can be tested using Levene's test or Bartlett’s test. If the variances are not equal, it might indicate that ANOVA is not appropriate, or a more robust method (like Welch’s ANOVA) should be used.

# %% [markdown]
# #21.What are the different types of ANOVA tests?
# Types of ANOVA Test:
# 1.One way Anova
# 2.Two way Anova
# 3.Repeated Measures ANOVA
# 4.Manova
# 5.Welch’s ANOVA
# 6.MixedDesign Anova

# %% [markdown]
# #22. What is the F-test, and how does it relate to hypothesis testing?
# The F-test is a statistical test used to compare two variances or to test the overall significance of a model, particularly in regression analysis and ANOVA (Analysis of Variance). It assesses whether the variances between two or more groups are significantly different or whether a model is a good fit for the data.

# %% [markdown]
# # Practical Part - 1

# %%
#1.Write a Python program to generate a random variable and display its value.
import random
random_variable = random.randint(1, 100)
print("Random Variable:", random_variable)
# Out:
# Random Variable: 13

# %%
#2.Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)?
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint
low = 1
high = 7
dist = randint(low, high)
x = np.arange(low, high)
pmf = dist.pmf(x)
plt.stem(x, pmf, basefmt=" ")
plt.title('Discrete Uniform Distribution PMF')
plt.xlabel('Value')
plt.ylabel('Probability')
plt.grid(True)
plt.xticks(x)
plt.ylim(0, 1)
plt.show()

# %%
#3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution?
def bernoulli_pdf(x, p):
    if x not in [0, 1]:
        raise ValueError("x must be 0 or 1 for a Bernoulli distribution.")
    if not (0 <= p <= 1):
        raise ValueError("Probability p must be between 0 and 1.")

    return p if x == 1 else (1 - p)
print(bernoulli_pdf(1, 0.7))  # Output: 0.7
print(bernoulli_pdf(0, 0.7))  # Output: 0.3
# Out:
# 0.7
# 0.30000000000000004

# %%
#4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.
import numpy as np
import matplotlib.pyplot as plt
n = 10
p = 0.5
size = 10000
data = np.random.binomial(n, p, size)
plt.hist(data, bins=np.arange(n+2)-0.5, density=True, edgecolor='black', alpha=0.75)
plt.title(f'Binomial Distribution Histogram (n={n}, p={p})')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(np.arange(n+1))
plt.grid(axis='y')
plt.show()

# %%
#5.Create a Poisson distribution and visualize it using Python.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson
mu = 4
x = np.arange(0, 15)
pmf = poisson.pmf(x, mu)
plt.stem(x, pmf, basefmt=" ")
plt.title(f'Poisson Distribution PMF (λ = {mu})')
plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.grid(True)
plt.xticks(x)
plt.show()

# %%
#6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint
low = 1
high = 7
dist = randint(low, high)
x = np.arange(low - 1, high + 1)
cdf = dist.cdf(x)
plt.step(x, cdf, where='post', label='CDF', color='blue')
plt.title('CDF of Discrete Uniform Distribution')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.grid(True)
plt.xticks(np.arange(low - 1, high + 1))
plt.yticks(np.linspace(0, 1, high - low + 2))
plt.ylim(0, 1.05)
plt.legend()
plt.show()

# %%
#7.Generate a continuous uniform distribution using NumPy and visualize it.
import numpy as np
import matplotlib.pyplot as plt
low = 0
high = 10
size = 10000
samples = np.random.uniform(low, high, size)
plt.hist(samples, bins=50, density=True, color='skyblue', edgecolor='black', alpha=0.7)
plt.hlines(1 / (high - low), xmin=low, xmax=high, colors='red', label='PDF', linewidth=2)
plt.title('Continuous Uniform Distribution')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.legend()
plt.show()

# %%
#8.Simulate data from a normal distribution and plot its histogram
import numpy as np
import matplotlib.pyplot as plt
mean = 0
std_dev = 1
size = 10000
data = np.random.normal(loc=mean, scale=std_dev, size=size)
plt.hist(data, bins=50, density=True, color='lightblue', edgecolor='black', alpha=0.7)
plt.title('Normal Distribution Histogram (μ=0, σ=1)')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
#9. Write a Python function to calculate Z-scores from a dataset and plot them.
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_z_scores(data):
    data = np.array(data)
    mean = np.mean(data)
    std = np.std(data)
    z_scores = (data - mean) / std
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.scatter(range(len(z_scores)), z_scores, color='blue', alpha=0.6)
    plt.axhline(0, color='red', linestyle='--')
    plt.title("Z-Scores (Scatter)")
    plt.xlabel("Data Point Index")
    plt.ylabel("Z-Score")
    plt.subplot(1, 2, 2)
    plt.hist(z_scores, bins=30, color='green', edgecolor='black', alpha=0.7)
    plt.title("Z-Scores (Histogram)")
    plt.xlabel("Z-Score")
    plt.ylabel("Frequency")

    plt.tight_layout()
    plt.show()

    return z_scores
data = np.random.normal(loc=50, scale=10, size=100)
z_scores = calculate_and_plot_z_scores(data)

# %%
#10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.
import numpy as np
import matplotlib.pyplot as plt

def demonstrate_clt(sample_size=30, num_samples=1000):
    original_data = np.random.exponential(scale=2.0, size=10000)
    sample_means = []

    for _ in range(num_samples):
        sample = np.random.choice(original_data, size=sample_size, replace=True)
        sample_means.append(np.mean(sample))
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.hist(original_data, bins=50, color='orange', edgecolor='black', alpha=0.7)
    plt.title('Original Exponential Distribution')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.subplot(1, 2, 2)
    plt.hist(sample_means, bins=40, color='skyblue', edgecolor='black', alpha=0.7, density=True)
    plt.title(f'Distribution of Sample Means (n={sample_size})')
    plt.xlabel('Sample Mean')
    plt.ylabel('Density')

    plt.tight_layout()
    plt.show()
demonstrate_clt(sample_size=30, num_samples=1000)

# %%
#11.Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def verify_clt_with_normal_dist(sample_size=30, num_samples=1000, mean=0, std_dev=1):
    sample_means = []

    for _ in range(num_samples):
        sample = np.random.normal(loc=mean, scale=std_dev, size=sample_size)
        sample_means.append(np.mean(sample))
    plt.figure(figsize=(10, 6))
    plt.hist(sample_means, bins=40, color='lightgreen', edgecolor='black', density=True, alpha=0.7)
    x = np.linspace(min(sample_means), max(sample_means), 100)
    sample_mean = mean
    sample_std = std_dev / np.sqrt(sample_size)
    plt.plot(x, norm.pdf(x, loc=sample_mean, scale=sample_std), 'r-', lw=2, label='Theoretical Normal PDF')
    plt.title(f'Distribution of Sample Means (CLT Verification)\nSample Size = {sample_size}, Num Samples = {num_samples}')
    plt.xlabel('Sample Mean')
    plt.ylabel('Density')
    plt.grid(True)
    plt.legend()
    plt.show()
verify_clt_with_normal_dist(sample_size=30, num_samples=1000, mean=0, std_dev=1)

# %%
#12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():
    x = np.linspace(-4, 4, 1000)
    y = norm.pdf(x, loc=0, scale=1)
    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label='Standard Normal Distribution', color='blue', lw=2)
    plt.title('Standard Normal Distribution (Mean=0, Std=1)', fontsize=14)
    plt.xlabel('x', fontsize=12)
    plt.ylabel('Probability Density', fontsize=12)
    plt.grid(True)
    plt.legend()
    plt.show()
plot_standard_normal_distribution()

# %%
#13.Generate random variables and calculate their corresponding probabilities using the binomial distribution.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

def binomial_distribution_example(n=10, p=0.5, size=1000):
    random_variables = np.random.binomial(n, p, size)
    values, counts = np.unique(random_variables, return_counts=True)
    probabilities = binom.pmf(values, n, p)
    print("Random Variables and Corresponding Probabilities:")
    for value, prob in zip(values, probabilities):
        print(f"Value: {value}, Probability: {prob:.4f}")
    plt.figure(figsize=(8, 5))
    plt.hist(random_variables, bins=np.arange(-0.5, n+1.5, 1), density=True, color='lightblue', edgecolor='black', alpha=0.7)
    x = np.arange(0, n+1)
    plt.plot(x, binom.pmf(x, n, p), 'ro', label='Theoretical PMF', markersize=10)
    plt.title(f'Binomial Distribution (n={n}, p={p})', fontsize=14)
    plt.xlabel('Number of Successes', fontsize=12)
    plt.ylabel('Probability', fontsize=12)
    plt.xticks(x)
    plt.grid(True)
    plt.legend()
    plt.show()
binomial_distribution_example(n=10, p=0.5, size=1000)
# Out:
# Random Variables and Corresponding Probabilities:
# Value: 1, Probability: 0.0098
# Value: 2, Probability: 0.0439
# Value: 3, Probability: 0.1172
# Value: 4, Probability: 0.2051
# Value: 5, Probability: 0.2461
# Value: 6, Probability: 0.2051
# Value: 7, Probability: 0.1172
# Value: 8, Probability: 0.0439
# Value: 9, Probability: 0.0098

# %%
#14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(data, x):
    data = np.array(data)
    mean = np.mean(data)
    std_dev = np.std(data)
    z_score = (x - mean) / std_dev
    cdf_value = norm.cdf(z_score)
    print(f"Z-score for {x}: {z_score:.4f}")
    print(f"Cumulative Probability (CDF) for Z-score {z_score:.4f}: {cdf_value:.4f}")

    return z_score

def plot_standard_normal_distribution(z_score):
    x = np.linspace(-4, 4, 1000)
    y = norm.pdf(x, loc=0, scale=1)
    plt.plot(x, y, label='Standard Normal Distribution', color='blue', lw=2)
    plt.axvline(x=z_score, color='red', linestyle='--', label=f'Z-score = {z_score:.2f}')
    plt.fill_between(x, y, where=(x >= z_score), color='red', alpha=0.3)
    plt.title(f'Standard Normal Distribution with Z-score = {z_score:.2f}')
    plt.xlabel('Z-score')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()
data = np.random.normal(loc=50, scale=10, size=1000)
x = 55

z_score = calculate_z_score(data, x)
plot_standard_normal_distribution(z_score)
# Out:
# Z-score for 55: 0.5146
# Cumulative Probability (CDF) for Z-score 0.5146: 0.6966

# %%
#15. Implement hypothesis testing using Z-statistics for a sample dataset.
import numpy as np
from scipy.stats import norm

def z_test(sample_data, population_mean, population_std, alpha=0.05):
    sample_data = np.array(sample_data)
    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)
    z_statistic = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
    p_value = 2 * (1 - norm.cdf(np.abs(z_statistic)))
    reject_null = p_value < alpha
    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Z-statistic: {z_statistic:.4f}")
    print(f"P-value: {p_value:.4f}")
    print(f"Reject null hypothesis: {'Yes' if reject_null else 'No'}")

    return z_statistic, p_value, reject_null
np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=10, size=100)
population_mean = 52
population_std = 10
z_statistic, p_value, reject_null = z_test(sample_data, population_mean, population_std, alpha=0.05)
# Out:
# Sample Mean: 48.9615
# Z-statistic: -3.0385
# P-value: 0.0024
# Reject null hypothesis: Yes

# %%
#16.Create a confidence interval for a dataset using Python and interpret the result.
import numpy as np
import scipy.stats as stats

def confidence_interval(data, confidence_level=0.95):
    data = np.array(data)
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)
    sample_size = len(data)
    t_critical = stats.t.ppf((1 + confidence_level) / 2, df=sample_size - 1)
    margin_of_error = t_critical * (sample_std / np.sqrt(sample_size))
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error
    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Sample Standard Deviation: {sample_std:.4f}")
    print(f"Sample Size: {sample_size}")
    print(f"Confidence Interval: ({lower_bound:.4f}, {upper_bound:.4f})")

    return lower_bound, upper_bound
np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=10, size=100)
lower_bound, upper_bound = confidence_interval(sample_data, confidence_level=0.95)
# Out:
# Sample Mean: 48.9615
# Sample Standard Deviation: 9.0817
# Sample Size: 100
# Confidence Interval: (47.1595, 50.7635)

# %%
#17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.
import numpy as np
import scipy.stats as stats

def confidence_interval_for_mean(data, confidence_level=0.95):
    data = np.array(data)
    sample_mean = np.mean
    sample_std = np.std(data, ddof=1)
    sample_size = len(data)
    t_critical = stats.t.ppf((1 + confidence_level) / 2, df=sample_size - 1)
    margin_of_error = t_critical * (sample_std / np.sqrt(sample_size))
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error
    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Sample Standard Deviation: {sample_std:.4f}")
    print(f"Sample Size: {sample_size}")
    print(f"Confidence Interval: ({lower_bound:.4f}, {upper_bound:.4f})")
    return lower_bound, upper_bound
np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=10, size=100)
lower_bound, upper_bound = confidence_interval(sample_data, confidence_level=0.95)
# Out:
# Sample Mean: 48.9615
# Sample Standard Deviation: 9.0817
# Sample Size: 100
# Confidence Interval: (47.1595, 50.7635)

# %%
#18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_normal_pdf(mean, std_dev, x_min=-10, x_max=10, num_points=1000):
    x = np.linspace(x_min, x_max, num_points)
    y = norm.pdf(x, loc=mean, scale=std_dev)
    plt.plot(x, y, label=f'Normal Distribution\nμ={mean}, σ={std_dev}')
    plt.title(f'Probability Density Function (PDF) of Normal Distribution')
    plt.xlabel('x')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.legend()
    plt.show()
mean = 0
std_dev = 1
plot_normal_pdf(mean, std_dev, x_min=-5, x_max=5)

# %%
#19.Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

def plot_poisson_cdf(lam, k_max):
    k_values = np.arange(0, k_max+1)
    cdf_values = poisson.cdf(k_values, lam)
    plt.step(k_values, cdf_values, where='post', label=f'Poisson CDF (λ={lam})', color='blue')
    plt.title('Cumulative Distribution Function (CDF) of Poisson Distribution')
    plt.xlabel('k')
    plt.ylabel('CDF')
    plt.grid(True)
    plt.legend()
    plt.show()
lambda_value = 3
k_max = 10
plot_poisson_cdf(lambda_value, k_max)

# %%
#20. Simulate a random variable using a continuous uniform distribution and calculate its expected value.
import numpy as np
a = 1  # Minimum value
b = 5  # Maximum value
random_samples = np.random.uniform(a, b, size=10000)
expected_value = (a + b) / 2
print(f"Expected value (E(X)) = {(a + b) / 2}")
sample_mean = np.mean(random_samples)
print(f"Sample mean of the simulated random variable: {sample_mean:.4f}")
# Out:
# Expected value (E(X)) = 3.0
# Sample mean of the simulated random variable: 2.9775

# %%
#21.Write a Python program to compare the standard deviations of two datasets and visualize the difference.
import numpy as np
import matplotlib.pyplot as plt
data1 = np.random.normal(loc=50, scale=5, size=1000)
data2 = np.random.normal(loc=50, scale=10, size=1000)
std_data1 = np.std(data1)
std_data2 = np.std(data2)
print(f"Standard deviation of Dataset 1: {std_data1:.4f}")
print(f"Standard deviation of Dataset 2: {std_data2:.4f}")
labels = ['Dataset 1', 'Dataset 2']
std_devs = [std_data1, std_data2]
plt.figure(figsize=(8, 6))
plt.bar(labels, std_devs, color=['blue', 'orange'])
plt.title("Comparison of Standard Deviations")
plt.ylabel("Standard Deviation")
plt.show()
plt.figure(figsize=(8, 6))
plt.boxplot([data1, data2], labels=labels, patch_artist=True, boxprops=dict(facecolor='skyblue', color='blue'))
plt.title("Boxplot Comparison of Datasets")
plt.ylabel("Value")
plt.show()
# Out:
# Standard deviation of Dataset 1: 5.0760
# Standard deviation of Dataset 2: 9.6297
# <ipython-input-25-c84f9b05e2e6>:18: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data1, data2], labels=labels, patch_artist=True, boxprops=dict(facecolor='skyblue', color='blue'))

# %%
#22.Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.
import numpy as np
data = np.random.normal(loc=50, scale=10, size=1000)
data_range = np.max(data) - np.min(data)
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
print(f"Range of the dataset: {data_range:.4f}")
print(f"Interquartile Range (IQR) of the dataset: {IQR:.4f}")
# Out:
# Range of the dataset: 61.4667
# Interquartile Range (IQR) of the dataset: 13.0199

# %%
#23. Implement Z-score normalization on a dataset and visualize its transformation.
import numpy as np
import matplotlib.pyplot as plt
data = np.random.normal(loc=50, scale=10, size=1000)
mean = np.mean(data)
std_dev = np.std(data)
normalized_data = (data - mean) / std_dev
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='blue', alpha=0.7)
plt.title('Original Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.subplot(1, 2, 2)
plt.hist(normalized_data, bins=30, color='green', alpha=0.7)
plt.title('Normalized Data Distribution (Z-score Normalized)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
print(f"Mean of original data: {mean:.4f}, Standard Deviation: {std_dev:.4f}")
print(f"Mean of normalized data: {np.mean(normalized_data):.4f}, Standard Deviation: {np.std(normalized_data):.4f}")
# Out:
# Mean of original data: 49.9076, Standard Deviation: 10.1463
# Mean of normalized data: -0.0000, Standard Deviation: 1.0000

# %%
#24.Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.
import numpy as np
from scipy.stats import skew, kurtosis
def calculate_skewness_kurtosis(data):
    skewness_value = skew(data)
    kurtosis_value = kurtosis(data)

    return skewness_value, kurtosis_value
data = np.random.normal(loc=50, scale=10, size=1000)
skewness_value, kurtosis_value = calculate_skewness_kurtosis(data)
print(f"Skewness of the dataset: {skewness_value:.4f}")
print(f"Kurtosis (excess kurtosis) of the dataset: {kurtosis_value:.4f}")
# Out:
# Skewness of the dataset: 0.0171
# Kurtosis (excess kurtosis) of the dataset: -0.0622

# %% [markdown]
# #Practical Part - 2

# %%
#1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.
import numpy as np
from scipy import stats
def z_test(sample, population_mean, population_std):
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    z_statistic = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
    p_value = 2 * (1 - stats.norm.cdf(abs(z_statistic)))

    return z_statistic, p_value
np.random.seed(42)
sample = np.random.normal(loc=50, scale=10, size=100)
population_mean = 50
population_std = 10
z_stat, p_value = z_test(sample, population_mean, population_std)
print(f"Z-statistic: {z_stat:.4f}")
print(f"P-value: {p_value:.4f}")
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.")
# Out:
# Z-statistic: -1.0385
# P-value: 0.2991
# Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.

# %%
#2.Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.
import numpy as np
from scipy import stats
np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=10, size=100)
population_mean = 50
t_statistic, p_value = stats.ttest_1samp(sample_data, population_mean)
print(f"T-statistic: {t_statistic:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.")
# Out:
# T-statistic: -1.1435
# P-value: 0.2556
# Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.

# %%
#3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean.
import numpy as np
from scipy.stats import norm
def z_test(sample, population_mean, population_std):
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    z_statistic = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
    p_value = 2 * (1 - norm.cdf(abs(z_statistic)))

    return z_statistic, p_value
np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=10, size=100)
population_mean = 50
population_std = 10
z_stat, p_value = z_test(sample_data, population_mean, population_std)
print(f"Z-statistic: {z_stat:.4f}")
print(f"P-value: {p_value:.4f}")
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.")
# Out:
# Z-statistic: -1.0385
# P-value: 0.2991
# Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.

# %%
#4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
def z_test(sample, population_mean, population_std):
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    z_statistic = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
    p_value = 2 * (1 - norm.cdf(abs(z_statistic)))

    return z_statistic, p_value
np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=10, size=100)
population_mean = 50
population_std = 10
z_stat, p_value = z_test(sample_data, population_mean, population_std)
print(f"Z-statistic: {z_stat:.4f}")
print(f"P-value: {p_value:.4f}")
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.")
z_critical = norm.ppf(1 - alpha/2)
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x, 0, 1)
plt.plot(x, y, label='Standard Normal Distribution')
plt.fill_between(x, y, where=(x <= -z_critical), color='red', alpha=0.3, label='Rejection Region (-∞ to -1.96)')
plt.fill_between(x, y, where=(x >= z_critical), color='red', alpha=0.3, label='Rejection Region (1.96 to ∞)')
plt.axvline(x=z_stat, color='orange', linestyle='--', label=f'Z-statistic: {z_stat:.4f}')
plt.title("Two-Tailed Z-Test - Decision Region")
plt.xlabel("Z-Score")
plt.ylabel("Probability Density")
plt.legend(loc='upper left')
plt.grid(True)
plt.show()
# Out:
# Z-statistic: -1.0385
# P-value: 0.2991
# Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.

# %%
#5.Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def visualize_type1_type2_errors(mu0, mu1, sigma, n, alpha=0.05, test_type='right'):
    se = sigma / np.sqrt(n)
    if test_type == 'right':
        z_crit = norm.ppf(1 - alpha)
        x_crit = mu0 + z_crit * se
    elif test_type == 'left':
        z_crit = norm.ppf(alpha)
        x_crit = mu0 + z_crit * se
    elif test_type == 'two-tailed':
        z_crit_right = norm.ppf(1 - alpha / 2)
        z_crit_left = norm.ppf(alpha / 2)
        x_crit_right = mu0 + z_crit_right * se
        x_crit_left = mu0 + z_crit_left * se
    x = np.linspace(mu0 - 4*se, mu1 + 4*se, 1000)
    y0 = norm.pdf(x, mu0, se)
    y1 = norm.pdf(x, mu1, se)
    plt.figure(figsize=(10, 6))
    plt.plot(x, y0, label='Null Hypothesis $H_0$', color='blue')
    plt.plot(x, y1, label='Alternative Hypothesis $H_1$', color='green')

    if test_type == 'right':
        # Type I Error: area to the right of critical value under H0
        plt.fill_between(x, y0, where=(x >= x_crit), color='red', alpha=0.3, label='Type I Error (α)')
        # Type II Error: area to the left of critical value under H1
        plt.fill_between(x, y1, where=(x < x_crit), color='orange', alpha=0.3, label='Type II Error (β)')
        plt.axvline(x_crit, color='black', linestyle='--', label=f'Critical Value = {x_crit:.2f}')

    elif test_type == 'left':
        plt.fill_between(x, y0, where=(x <= x_crit), color='red', alpha=0.3, label='Type I Error (α)')
        plt.fill_between(x, y1, where=(x > x_crit), color='orange', alpha=0.3, label='Type II Error (β)')
        plt.axvline(x_crit, color='black', linestyle='--', label=f'Critical Value = {x_crit:.2f}')

    elif test_type == 'two-tailed':
        plt.fill_between(x, y0, where=(x <= x_crit_left) | (x >= x_crit_right), color='red', alpha=0.3, label='Type I Error (α)')
        plt.fill_between(x, y1, where=(x > x_crit_left) & (x < x_crit_right), color='orange', alpha=0.3, label='Type II Error (β)')
        plt.axvline(x_crit_left, color='black', linestyle='--', label=f'Left Critical = {x_crit_left:.2f}')
        plt.axvline(x_crit_right, color='black', linestyle='--', label=f'Right Critical = {x_crit_right:.2f}')
    plt.title('Type I and Type II Error Visualization')
    plt.xlabel('Sample Mean')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()
visualize_type1_type2_errors(mu0=100, mu1=105, sigma=15, n=36, alpha=0.05, test_type='right')

# %%
#6.Write a Python program to perform an independent T-test and interpret the results.
import numpy as np
from scipy.stats import ttest_ind
np.random.seed(0)
group1 = np.random.normal(loc=50, scale=10, size=30)
group2 = np.random.normal(loc=55, scale=10, size=30)
t_stat, p_value = ttest_ind(group1, group2, equal_var=True)
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The group means are significantly different.")
else:
    print("Fail to reject the null hypothesis: No significant difference between group means.")
# Out:
# T-statistic: 0.8897
# P-value: 0.3773
# Fail to reject the null hypothesis: No significant difference between group means.

# %%
#7.Perform a paired sample T-test using Python and visualize the comparison results.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel
np.random.seed(42)
before = np.random.normal(loc=70, scale=5, size=30)
after = before + np.random.normal(loc=3, scale=5, size=30)
t_stat, p_value = ttest_rel(before, after)
print(f"Paired T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference (e.g. improvement).")
else:
    print("Fail to reject the null hypothesis: No significant difference found.")
plt.figure(figsize=(10, 6))
x = np.arange(len(before))
plt.plot(x, before, 'o-', label='Before')
plt.plot(x, after, 's-', label='After')
plt.title('Before vs. After - Paired Sample Comparison')
plt.xlabel('Subject Index')
plt.ylabel('Score')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Paired T-statistic: -2.8168
# P-value: 0.0086
# Reject the null hypothesis: There is a significant difference (e.g. improvement).

# %%
#8.Simulate data and perform both Z-test and T-test, then compare the results using Python.
import numpy as np
from scipy.stats import norm, ttest_1samp
np.random.seed(42)
sample_size = 30
true_mean = 50
population_std = 10
sample = np.random.normal(loc=true_mean, scale=population_std, size=sample_size)
hypothesized_mean = 52
sample_mean = np.mean(sample)
se = population_std / np.sqrt(sample_size)
z_stat = (sample_mean - hypothesized_mean) / se
z_p_value = 2 * (1 - norm.cdf(abs(z_stat)))
t_stat, t_p_value = ttest_1samp(sample, popmean=hypothesized_mean)
print("=== Z-test ===")
print(f"Z-statistic: {z_stat:.4f}")
print(f"P-value:     {z_p_value:.4f}")

print("\n=== T-test ===")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value:     {t_p_value:.4f}")
alpha = 0.05
print("\n=== Interpretation ===")
if z_p_value < alpha:
    print("Z-test: Reject the null hypothesis")
else:
    print("Z-test: Fail to reject the null hypothesis")

if t_p_value < alpha:
    print("T-test: Reject the null hypothesis")
else:
    print("T-test: Fail to reject the null hypothesis")
# Out:
# === Z-test ===
# Z-statistic: -2.1260
# P-value:     0.0335
#
# === T-test ===
# T-statistic: -2.3622
# P-value:     0.0251
#
# === Interpretation ===
# Z-test: Reject the null hypothesis
# T-test: Reject the null hypothesis

# %%
#9.Write a Python function to calculate the confidence interval for a sample mean and explain its significance.
import numpy as np
from scipy.stats import t

def confidence_interval(data, confidence=0.95):
    data = np.array(data)
    n = len(data)
    mean = np.mean(data)
    std_err = np.std(data, ddof=1) / np.sqrt(n)
    t_crit = t.ppf((1 + confidence) / 2, df=n-1)

    margin_of_error = t_crit * std_err
    lower = mean - margin_of_error
    upper = mean + margin_of_error

    return lower, upper

np.random.seed(0)
sample = np.random.normal(loc=100, scale=15, size=25)

ci = confidence_interval(sample, confidence=0.95)
print(f"95% Confidence Interval: ({ci[0]:.2f}, {ci[1]:.2f})")
# Out:
# 95% Confidence Interval: (100.36, 113.90)

# %%
#10. Write a Python program to calculate the margin of error for a given confidence level using sample data.
import numpy as np
from scipy.stats import t

def margin_of_error(data, confidence=0.95):
    data = np.array(data)
    n = len(data)
    std_dev = np.std(data, ddof=1)
    std_err = std_dev / np.sqrt(n)
    t_crit = t.ppf((1 + confidence) / 2, df=n - 1)
    moe = t_crit * std_err
    return moe

np.random.seed(42)
sample_data = np.random.normal(loc=100, scale=15, size=30)
moe = margin_of_error(sample_data, confidence=0.95)
print(f"Margin of Error (95% confidence): ±{moe:.2f}")
# Out:
# Margin of Error (95% confidence): ±5.04

# %%
#11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.
from scipy.stats import binom

def bayesian_inference(prior_A, prior_B, flips, heads):
    likelihood_A = binom.pmf(heads, flips, 0.5)
    likelihood_B = binom.pmf(heads, flips, 0.8)
    evidence = (likelihood_A * prior_A) + (likelihood_B * prior_B)
    posterior_A = (likelihood_A * prior_A) / evidence
    posterior_B = (likelihood_B * prior_B) / evidence

    return {
        'Posterior_A': posterior_A,
        'Posterior_B': posterior_B
    }
prior_A = 0.5
prior_B = 0.5
flips = 5
heads = 4
posteriors = bayesian_inference(prior_A, prior_B, flips, heads)
print("Posterior probabilities after observing 4 heads in 5 flips:")
print(f"Coin A (fair):  {posteriors['Posterior_A']:.4f}")
print(f"Coin B (biased): {posteriors['Posterior_B']:.4f}")
# Out:
# Posterior probabilities after observing 4 heads in 5 flips:
# Coin A (fair):  0.2761
# Coin B (biased): 0.7239

# %%
#12.Perform a Chi-square test for independence between two categorical variables in Python.
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency
data = np.array([[30, 10],
                 [20, 40]])
contingency_table = pd.DataFrame(data,
                                 index=['Young', 'Old'],
                                 columns=['Coffee', 'Tea'])

print("Contingency Table:\n", contingency_table)
chi2_stat, p_val, dof, expected = chi2_contingency(contingency_table)
print(f"\nChi-square Statistic: {chi2_stat:.4f}")
print(f"Degrees of Freedom: {dof}")
print(f"P-value: {p_val:.4f}")
print("\nExpected Frequencies:\n", pd.DataFrame(expected,
                                                index=['Young', 'Old'],
                                                columns=['Coffee', 'Tea']))
# Out:
# Contingency Table:
#         Coffee  Tea
# Young      30   10
# Old        20   40
#
# Chi-square Statistic: 15.0417
# Degrees of Freedom: 1
# P-value: 0.0001
#
# Expected Frequencies:
#         Coffee   Tea
# Young    20.0  20.0
# Old      30.0  30.0

# %%
#13.Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.
import numpy as np
import pandas as pd

def calculate_expected_frequencies(observed):
    if not isinstance(observed, pd.DataFrame):
        raise ValueError("Input must be a pandas DataFrame for labeling clarity.")
    row_totals = observed.sum(axis=1)
    col_totals = observed.sum(axis=0)
    grand_total = observed.values.sum()
    expected = np.outer(row_totals, col_totals) / grand_total
    return pd.DataFrame(expected, index=observed.index, columns=observed.columns)
data = pd.DataFrame({
    'Coffee': [30, 20],
    'Tea': [10, 40]
}, index=['Young', 'Old'])

print("Observed Frequencies:")
print(data)

expected = calculate_expected_frequencies(data)

print("\nExpected Frequencies (assuming independence):")
print(expected.round(2))
# Out:
# Observed Frequencies:
#        Coffee  Tea
# Young      30   10
# Old        20   40
#
# Expected Frequencies (assuming independence):
#        Coffee   Tea
# Young    20.0  20.0
# Old      30.0  30.0

# %%
#14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.
import numpy as np
from scipy.stats import chisquare
observed = np.array([8, 9, 10, 11, 12, 10])
expected = np.full(6, 10)
chi2_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

print(f"Chi-square Statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The observed distribution differs from expected.")
else:
    print("Fail to reject the null hypothesis: No significant difference found.")
# Out:
# Chi-square Statistic: 1.0000
# P-value: 0.9626
# Fail to reject the null hypothesis: No significant difference found.
